# %%
import pandas as pd
import numpy as np
import matplotlib  
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr

# %%
df=pd.read_csv('city_data_ulti.csv',sep=',')
df
# Out:
#                             city  unsheltered_ratio unsheltered_homeless  \
# 0                    Wheeling,WV           0.000107                    3
# 1                     Holland,MI           0.000119                    4
# 2                  Somerville,MA           0.000076                    6
# 3                     Jackson,MI           0.000209                    7
# 4                     Portage,MI           0.000168                    8
# 5                 SomersPoint,NJ           0.000834                    9
# 6                      Nashua,NH           0.000149                   13
# 7                      Aurora,IL           0.000070                   14
# 8                   Rochester,MN           0.000126                   14
# 9                      Toledo,OH           0.000053                   15
# 10                 Huntington,IN           0.000930                   16
# 11                      Utica,NY           0.000275                   17
# ...

# %%
df.columns
# Out:
# Index(['city', 'unsheltered_ratio', 'unsheltered_homeless', 'population',
#        'mean_housing_unit_price', 'weather_temp',
#        'household_income_disparities', 'estimated_per_capita_income',
#        'government_finances_current_operations_judical_and_legal_serices_per_resident',
#        'poverty_percentage', 'urban_population_percent',
#        'government_finances_current_operations_health_other_per_resident'],
#       dtype='object')

# %%
fig = plt.figure()  
ax1 = fig.add_subplot(111) 
ax1.set_title('unsheltered ratio / mean housing unit price')
ax1.scatter(df[df.columns[4]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[4]],df[df.columns[1]])
# Out:
# (-0.14608207735993214, 0.12604960065378007)

# %%
fig = plt.figure()
ax2 = fig.add_subplot(111) 
ax2.set_title('unsheltered ratio / weather temp')
ax2.scatter(df[df.columns[5]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[5]],df[df.columns[1]])
# Out:
# (0.1826219128594918, 0.05505690446535575)

# %%
fig = plt.figure()
ax3 = fig.add_subplot(111) 
ax3.set_title('unsheltered ratio / household income disparities')
ax3.scatter(df[df.columns[6]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[6]],df[df.columns[1]])
# Out:
# (-0.21244597056172804, 0.025185969824416326)

# %%
fig = plt.figure()
ax4 = fig.add_subplot(111) 
ax4.set_title('unsheltered ratio / estimated per capita income($)')
ax4.scatter(df[df.columns[7]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[7]],df[df.columns[1]])
# Out:
# (0.051081864598887694, 0.5944237703223285)

# %%
fig = plt.figure()
ax5 = fig.add_subplot(111) 
ax5.set_title('unsheltered ratio / government finances-current operations judical and legal serices - per resident')
ax5.scatter(df[df.columns[8]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[8]],df[df.columns[1]])
# Out:
# (-0.030965335006071276, 0.7469797264327285)

# %%
fig = plt.figure()
ax6 = fig.add_subplot(111) 
ax6.set_title('unsheltered ratio / poverty percentage')
ax6.scatter(df[df.columns[9]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[9]],df[df.columns[1]])
# Out:
# (-0.23352750527663385, 0.01363564400987298)

# %%
fig = plt.figure()
ax7 = fig.add_subplot(111) 
ax7.set_title('unsheltered ratio / urban population %')
ax7.scatter(df[df.columns[10]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[10]],df[df.columns[1]])
# Out:
# (0.07474996023627513, 0.43555780514188436)

# %%
fig = plt.figure()
ax8 = fig.add_subplot(111) 
ax8.set_title('unsheltered ratio / government finances-current operations health other - per resident')
ax8.scatter(df[df.columns[11]],df[df.columns[1]]*1000)

# %%
pearsonr(df[df.columns[11]],df[df.columns[1]])
# Out:
# (-0.1845110920862416, 0.05254778912055436)

# %%
import statsmodels.api as sm
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from statsmodels.formula.api import ols

# %%
col = df.columns
col = list(col[4:])
col
# Out:
# ['mean_housing_unit_price',
#  'weather_temp',
#  'household_income_disparities',
#  'estimated_per_capita_income',
#  'government_finances_current_operations_judical_and_legal_serices_per_resident',
#  'poverty_percentage',
#  'urban_population_percent',
#  'government_finances_current_operations_health_other_per_resident']

# %%
y = df['unsheltered_ratio']
X = df[col]
X = sm.add_constant(X)
#X = np.asarray(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)
mod = sm.OLS(y_train, X_train.astype(float))
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      unsheltered_ratio   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     7.201
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):           3.99e-07
# Time:                        15:58:04   Log-Likelihood:                 364.17
# No. Observations:                  88   AIC:                            -710.3
# Df Residuals:                      79   BIC:                            -688.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
pred = res.predict(X_test)
pred = np.array(pred)
r = np.array(y_test)
mean_squared_error(pred, r)
# Out:
# 8.75907054190742e-05

# %%
# kick out poverty percentage

# %%
col2 = col[:5] + col[6:]
col2
# Out:
# ['mean_housing_unit_price',
#  'weather_temp',
#  'household_income_disparities',
#  'estimated_per_capita_income',
#  'government_finances_current_operations_judical_and_legal_serices_per_resident',
#  'urban_population_percent',
#  'government_finances_current_operations_health_other_per_resident']

# %%
y2 = df['unsheltered_ratio']
X2 = df[col2]
X2 = sm.add_constant(X2)
#X = np.asarray(X)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=23)
mod2 = sm.OLS(y_train2, X_train2.astype(float))
res2 = mod2.fit()
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      unsheltered_ratio   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     8.295
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):           1.40e-07
# Time:                        15:58:07   Log-Likelihood:                 364.09
# No. Observations:                  88   AIC:                            -712.2
# Df Residuals:                      80   BIC:                            -692.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                                                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
pred2 = res2.predict(X_test2)
pred2 = np.array(pred2)
r2 = np.array(y_test2)
mean_squared_error(pred2, r2)
# Out:
# 8.699115340008173e-05

# %%
'''
keep the best five:
mean_housing_unit_price
weather_temp
household_income_disparities
estimated_per_capita_income
government_finances_current_operations_judical_and_legal_serices_per_resident
'''

# %%
all_train2 = X_train2.join(y_train2)

# %%
mod = ols(formula='unsheltered_ratio ~ mean_housing_unit_price * weather_temp + mean_housing_unit_price*household_income_disparities + mean_housing_unit_price*estimated_per_capita_income + mean_housing_unit_price*government_finances_current_operations_judical_and_legal_serices_per_resident + weather_temp*household_income_disparities + weather_temp*estimated_per_capita_income + weather_temp*government_finances_current_operations_judical_and_legal_serices_per_resident + household_income_disparities*estimated_per_capita_income + household_income_disparities*government_finances_current_operations_judical_and_legal_serices_per_resident + estimated_per_capita_income*government_finances_current_operations_judical_and_legal_serices_per_resident', data=all_train2)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      unsheltered_ratio   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     5.765
# Date:                Tue, 10 Apr 2018   Prob (F-statistic):           1.39e-07
# Time:                        16:20:03   Log-Likelihood:                 374.79
# No. Observations:                  88   AIC:                            -717.6
# Df Residuals:                      72   BIC:                            -677.9
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
k = df['unsheltered_ratio']
k = sorted(k)
print(k[0],k[55],k[110])
# Out:
# 5.31e-05 0.001059667 0.032952389

# %%
y_da = []
for i in range(len(df['unsheltered_ratio'])):
    if df['unsheltered_ratio'][i] <= 0.001:
        y_da.append([1,0])
    if df['unsheltered_ratio'][i] > 0.001:
        y_da.append([0,1])
y_da = np.array(y_da)

# %%
'''
keep the best five:
mean_housing_unit_price
weather_temp
household_income_disparities
estimated_per_capita_income
government_finances_current_operations_judical_and_legal_serices_per_resident
'''
col0 = [col[0], col[1], col[2], col[3], col[4]]
col0
# Out:
# ['mean_housing_unit_price',
#  'weather_temp',
#  'household_income_disparities',
#  'estimated_per_capita_income',
#  'government_finances_current_operations_judical_and_legal_serices_per_resident']

# %%
X_da = df[col]
X_da = X_da.astype('float32')
X_da = np.array(X_da)

# %%
X_da[:,0] = sklearn.preprocessing.scale(X_da[:,0])
X_da[:,1] = sklearn.preprocessing.scale(X_da[:,1])
X_da[:,2] = sklearn.preprocessing.scale(X_da[:,2])
X_da[:,3] = sklearn.preprocessing.scale(X_da[:,3])
X_da[:,4] = sklearn.preprocessing.scale(X_da[:,4])
X_da[:,5] = sklearn.preprocessing.scale(X_da[:,5])
X_da[:,6] = sklearn.preprocessing.scale(X_da[:,6])
X_da[:,7] = sklearn.preprocessing.scale(X_da[:,7])
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:181: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "

# %%
X_da
# Out:
# array([[-1.0529734 , -0.37881517,  1.3171817 , -0.23986316, -0.68200845,
#          0.4265072 ,  0.29235518, -0.5226895 ],
#        [-1.0393221 , -0.8558646 , -1.0458637 , -0.7470726 , -0.93071955,
#         -0.7760638 ,  0.22256847, -0.22911863],
#        [ 0.21583061, -0.6741317 , -0.54308826,  1.7687747 , -0.6448686 ,
#         -0.46729562,  0.36214194, -0.21267866],
#        [-1.2196044 , -0.9580896 , -0.41739434, -1.6593124 , -0.90568155,
#          0.6865226 ,  0.36214194, -0.5226895 ],
#        [-0.9441958 , -0.8558646 , -0.9201699 ,  0.4233427 , -0.91569674,
#         -1.7169946 , -0.4753096 , -0.5226895 ],
#        [-0.7767714 , -0.21979898, -1.4229454 , -0.05998074, -0.03352316,
#         -1.3643488 ,  0.36214194, -0.5226895 ],
#        [-0.48939282, -0.9808059 , -1.1212798 ,  0.59157705, -0.7625474 ,
#         -1.4001008 , -0.12637056, -0.13517593],
#        [-0.18060067, -0.9126562 , -1.2469738 , -0.1292797 , -0.69494474,
#         -1.117334  ,  0.29235518, -0.28548425],
# ...

# %%
from __future__ import print_function
import tensorflow as tf
import keras
import sklearn
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X_da, y_da, test_size=0.2, random_state=24)

# %%
batch_size = 10
num_classes = 2
epochs = 20

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_shape=(8,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(0.01),
              metrics=['accuracy'])

history = model.fit(Xtrain, ytrain,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(Xtest, ytest))
score = model.evaluate(Xtest, ytest, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_166 (Dense)            (None, 8)                 72
# _________________________________________________________________
# dropout_86 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_167 (Dense)            (None, 2)                 18
# ...
# Total params: 90
# Trainable params: 90
# Non-trainable params: 0
# _________________________________________________________________
# Train on 88 samples, validate on 23 samples
# Epoch 1/20
# 88/88 [==============================] - 2s 21ms/step - loss: 0.7463 - acc: 0.5227 - val_loss: 0.6945 - val_acc: 0.4783
# Epoch 2/20
# 88/88 [==============================] - 0s 375us/step - loss: 0.6727 - acc: 0.5795 - val_loss: 0.7068 - val_acc: 0.5652
# Epoch 3/20
# ...

# %%
pr = model.predict(Xtest)
pr
# Out:
# array([[0.30077198, 0.69922805],
#        [0.2398062 , 0.7601938 ],
#        [0.6562216 , 0.34377846],
#        [0.71802694, 0.28197306],
#        [0.4671087 , 0.5328913 ],
#        [0.5250586 , 0.4749413 ],
#        [0.7326567 , 0.26734325],
#        [0.5522196 , 0.44778037],
#        [0.7306915 , 0.26930848],
#        [0.6469726 , 0.35302734],
#        [0.164847  , 0.835153  ],
#        [0.20916185, 0.7908382 ],
#        [0.47209656, 0.5279035 ],
#        [0.7274035 , 0.27259648],
#        [0.24095318, 0.75904685],
#        [0.69648576, 0.3035143 ],
#        [0.73389316, 0.2661068 ],
#        [0.57844794, 0.42155206],
#        [0.5615464 , 0.43845356],
#        [0.29064083, 0.70935917],
#        [0.18632632, 0.8136737 ],
#        [0.4286606 , 0.5713394 ],
#        [0.35421136, 0.64578867]], dtype=float32)

# %%
m = []
for i in pr:
    if i[0]>i[1]:
        m.append([1,0])
    else:
        m.append([0,1])
q = 0
m = np.array(m)
for i in range(len(m)):
    if m[i][0] == ytest[i][0]:
        q += 1
q
# Out:
# 16
